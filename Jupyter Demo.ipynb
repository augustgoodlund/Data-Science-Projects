# %%
import pandas as pd

# %%
data=pd.read_csv('customers.csv')

# %%
data.head()
# Out:
#   Customer Id    Customer Name                VIN        Location  \
# 0     CUS1008     Silvia Stone  1GCBS1941RP397653      Glen Allen
# 1     CUS1009        Billy Kid  1GCBS1941LK397654      Midlothian
# 2     CUS1014     Rita Skeeter  1GCBS1943FK397789      Woodbridge
# 3     CUS1015    Alastor Moody  1GKBS1941RK367993  Fredericksburg
# 4     CUS1016  Pansy Parkinson  1GCRS197FGK396789      Brandywine
#
#         Street Address State            City    Zip       Phone  \
# 0          123 Nope Dr    VA      Glen Allen  23060  8043462277
# 1        234B Leafy St    VA      Midlothian  23114  8043797264
# 2          2343 Blanco    VA      Woodbridge  22192  7035766550
# 3    643 Warzbach PKWY    VA  Fredericksburg  22407  5407107781
# 4  912 Silver Sands Dr    MD      Brandywine  20613  3017822942
#
#                    Email
# 0  SilviaStone@yahoo.com
# 1    Billy_Kid@gmail.com
# 2    RitaSkeeter@aol.com
# 3    Alastor23@gmail.com
# 4   PParkinson@gmail.com

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import sklearn as sk
from sklearn import datasets, linear_model

# %%
data.describe()
# Out:
#                No  transaction    houseAge  distanceToNearestMRTstation  \
# count  418.000000   418.000000  418.000000                   418.000000
# mean   207.861244  2013.150335   17.620335                  1089.531764
# std    119.186994     0.282404   11.428348                  1265.798991
# min      1.000000  2012.667000    0.000000                    23.382840
# 25%    105.250000  2012.917000    8.900000                   289.324800
# 50%    209.500000  2013.167000   16.100000                   492.231300
# 75%    309.750000  2013.417000   28.150000                  1455.798000
# max    414.000000  2013.583000   43.800000                  6488.021000
#
#        numberOfConvenienceStores    latitude   longitude  housePriceOfUnitArea
# count                 418.000000  418.000000  418.000000            415.000000
# mean                    4.055024   24.968986  121.533262             38.033735
# std                     2.944627    0.012441    0.015371             13.685034
# ...

# %%
data.dtypes
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
#normalizing the data

# %%
data.houseAge.mean()
# Out:
# 17.620334928229664

# %%
data.houseAge.min()
# Out:
# 0.0

# %%
data.houseAge.max()
# Out:
# 43.8

# %%
data.houseAge.std()
# Out:
# 11.428348063298536

# %%
houseAgeStandardized=data.houseAge

# %%
norm=(houseAgeStandardized-houseAgeStandardized.mean())/houseAgeStandardized.std()
norm
# Out:
# 0      1.258245
# 1      0.164474
# 2     -0.378037
# 3     -0.378037
# 4     -1.104301
#          ...
# 413   -0.343036
# 414   -1.051800
# 415    0.103223
# 416   -0.833046
# 417   -0.973048
# Name: houseAge, Length: 418, dtype: float64

# %%
#finding the min and max values

# %%
minmax=(houseAgeStandardized - houseAgeStandardized.min())/(houseAgeStandardized.max()-houseAgeStandardized.min())
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax.min()
# Out:
# 0.0

# %%
minmax.max()
# Out:
# 1.0

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data['houseAgeStandardized']=norm

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    houseAgeStandardized
# 0              1.258245
# 1              0.164474
# 2             -0.378037
# 3             -0.378037
# 4             -1.104301

# %%
#dropping columns

# %%
data.drop(columns=['numberOfConvenienceStores'], inplace=True)

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
#changing column name

# %%
data.rename({'transaction': 'transactionDate'}, axis=1, inplace=True)

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
#using .loc[]

# %%
data.loc[0:10, :]
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
#using .iloc[]

# %%
data.iloc[1:11, :]
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 1    2         2012.917      19.5                     306.5947  24.98034
# 2    3         2013.583      13.3                     561.9845  24.98746
# 3    4         2013.500      13.3                     561.9845  24.98746
# 4    5         2012.833       5.0                     390.5684  24.97937
# 5    6         2012.667       7.1                    2175.0300  24.96305
# 6    7         2012.667      34.5                     623.4731  24.97933
# 7    8         2013.417      20.3                     287.6025  24.98042
# 8    9         2013.500      31.7                    5512.0380  24.95095
# 9   10         2013.417      17.9                    1783.1800  24.96731
# 10  11         2013.083      34.8                     405.2134  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 1   121.53951                  42.2              0.164474
# ...

# %%
#replacing NaN values with the mean

# %%
data.housePriceOfUnitArea.mean()
# Out:
# 38.03373493975904

# %%
data.fillna(value={'housePriceOfUnitArea':38.034}, inplace=True)

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
#identifying and dropping duplicate data

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...
